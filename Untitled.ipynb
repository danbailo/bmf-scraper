# %%
import pandas as pd

# %%
df = pd.read_html("http://www2.bmf.com.br/pages/portal/bmfbovespa/lumis/lum-tipo-de-participante-enUS.asp")

# %%
df[0].dropna()
# Out:
#                    Unnamed: 0_level_0      Long             Short
#                    Unnamed: 0_level_1 Contracts       % Contracts       %
#                    Unnamed: 0_level_2      Long    Long     Short   Short
#                    Unnamed: 0_level_3 Contracts       % Contracts       %
#                    Unnamed: 0_level_4      Long    Long     Short   Short
#                    Unnamed: 0_level_5 Contracts       % Contracts       %
#                    Unnamed: 0_level_6      Long    Long     Short   Short
#                    Unnamed: 0_level_7 Contracts       % Contracts       %
#                    Unnamed: 0_level_8      Long    Long     Short   Short
#                    Unnamed: 0_level_9 Contracts       % Contracts       %
#                   Unnamed: 0_level_10      Long    Long     Short   Short
#                   Unnamed: 0_level_11 Contracts       % Contracts       %
#                   Unnamed: 0_level_12      Long    Long     Short   Short
# ...
